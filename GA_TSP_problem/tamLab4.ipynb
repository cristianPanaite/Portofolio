# %%
from random import randint

class GA:
    def __init__(self, param = None, problParam = None):
        self.__param = param
        self.__problParam = problParam
        self.__population = []
        
    @property
    def population(self):
        return self.__population
    
    def initialisation(self):
        for _ in range(0, self.__param['popSize']):
            c = Chromosome(self.__problParam)
            self.__population.append(c)
    
    def evaluation(self):
        for c in self.__population:
            c.fitness = self.__problParam['function'](c.repres)
            
    def bestChromosome(self):
        best = self.__population[0]
        for c in self.__population:
            if (c.fitness < best.fitness):
                best = c
        return best
        
    def worstChromosome(self):
        best = self.__population[0]
        for c in self.__population:
            if (c.fitness > best.fitness):
                best = c
        return best

    def selection(self):
        pos1 = randint(0, self.__param['popSize'] - 1)
        pos2 = randint(0, self.__param['popSize'] - 1)
        if (self.__population[pos1].fitness < self.__population[pos2].fitness):
            return pos1
        else:
            return pos2 
        
    
    def oneGeneration(self):
        newPop = []
        for _ in range(self.__param['popSize']):
            p1 = self.__population[self.selection()]
            p2 = self.__population[self.selection()]
            off = p1.crossover(p2)
            off.mutation()
            newPop.append(off)
        self.__population = newPop
        self.evaluation()

    def oneGenerationElitism(self):
        newPop = [self.bestChromosome()]
        for _ in range(self.__param['popSize'] - 1):
            p1 = self.__population[self.selection()]
            p2 = self.__population[self.selection()]
            off = p1.crossover(p2)
            off.mutation()
            newPop.append(off)
        self.__population = newPop
        self.evaluation()
        
    def oneGenerationSteadyState(self):
        for _ in range(self.__param['popSize']):
            p1 = self.__population[self.selection()]
            p2 = self.__population[self.selection()]
            off = p1.crossover(p2)
            off.mutation()
            off.fitness = self.__problParam['function'](off.repres)
            worst = self.worstChromosome()
            if (off.fitness < worst.fitness):
                worst = off

# %%
def generateARandomPermutation(n):
    perm = [i for i in range(1, n)]
    pos1 = randint(0, n - 2)
    pos2 = randint(0, n - 2)
    perm[pos1], perm[pos2] = perm[pos2], perm[pos1]
    return perm

def generateNewValue(lim1, lim2):
    return randint(lim1, lim2)

def binToInt(x):
    val = 0
    # x.reverse()
    for bit in x:
        val = val * 2 + bit
    return val

# %%
class Chromosome:
    def __init__(self, problParam = None):
        self.__problParam = problParam  #problParam has to store the number of nodes/cities
        self.__repres = generateARandomPermutation(self.__problParam['noNodes'])
        self.__fitness = 0.0
    
    @property
    def repres(self):
        return self.__repres 
    
    @property
    def fitness(self):
        return self.__fitness 
    
    @repres.setter
    def repres(self, l = []):
        self.__repres = l 
    
    @fitness.setter 
    def fitness(self, fit = 0.0):
        self.__fitness = fit 
    
    def crossover(self, c):
        # order XO
        pos1 = randint(-1, self.__problParam['noNodes'] - 1)
        pos2 = randint(-1, self.__problParam['noNodes'] - 1)
        if (pos2 < pos1):
            pos1, pos2 = pos2, pos1 
        k = 0
        newrepres = self.__repres[pos1 : pos2]
        for el in c.__repres[pos2:] +c.__repres[:pos2]:
            if (el not in newrepres):
                if (len(newrepres) < self.__problParam['noNodes'] - pos1):
                    newrepres.append(el)
                else:
                    newrepres.insert(k, el)
                    k += 1

        offspring = Chromosome(self.__problParam)
        offspring.repres = newrepres
        return offspring
    
    def mutation(self):
        # insert mutation
        pos1 = randint(0, self.__problParam['noNodes'] - 2)
        pos2 = randint(0, self.__problParam['noNodes'] - 2)
        if (pos2 < pos1):
            pos1, pos2 = pos2, pos1
        el = self.__repres[pos2]
        del self.__repres[pos2]
        self.__repres.insert(pos1 + 1, el)
        
    def __str__(self):
        return "\nChromo: " + str(self.__repres) + " has fit: " + str(self.__fitness)
    
    def __repr__(self):
        return self.__str__()
    
    def __eq__(self, c):
        return self.__repres == c.__repres and self.__fitness == c.__fitness

# %%
def readFromFile(filename):
    nr_of_nodes = 0
    matrix_of_costs = []
    start = 0
    finish = 0
    with open(filename, "r") as reader:
        nr_of_nodes = int(reader.readline())
        for i in range(nr_of_nodes):
            nodes = reader.readline()
            nodes = nodes.split(",")
            nodes_value = []
            for n in nodes:
                nodes_value.append(int(n))
            matrix_of_costs.append(nodes_value)
    return [nr_of_nodes, matrix_of_costs]


def writeToFile(filenameOut, data):
    with open(filenameOut, "w+") as writer:
        writer.write(str(data[0]))
        writer.write("\n")
    data.pop(0)
    with open(filenameOut, "a") as writer:
        for line in data:
            writer.write(str(line))
            writer.write("\n")

# %%
def fitnessFunction(permutation, matrixOfCosts):
    lastNodeIndex = 0
    cost = 0
    for node in permutation:
        cost += matrixOfCosts[lastNodeIndex][node]
        lastNodeIndex = node
    cost += matrixOfCosts[lastNodeIndex][0]
    return cost

# %%
import random

nrOfNodes, matrixOfCosts = readFromFile("data.txt")
gaParam = {'popSize': 100, 'noGen': 100}
funct = lambda x: fitnessFunction(x, matrixOfCosts)
problParam = {"noNodes": nrOfNodes, "function": funct}

ga = GA(gaParam, problParam)
ga.initialisation()
ga.evaluation()

min = 100000000
path = []

for g in range(gaParam['noGen']):
#     logic alg
#     ga.oneGeneration()
    ga.oneGenerationElitism()
#    ga.oneGenerationSteadyState()

    bestChromo = ga.bestChromosome()
    print('Best solution in generation ' + str(g) + ' is: x = ' + str(bestChromo.repres) + ' f(x) = ' + str(bestChromo.fitness))
    if bestChromo.fitness < min:
        min = bestChromo.fitness
        path = bestChromo.repres
print("Best path: ", [0] + path)
print("With cost:", min)
# Out:
# Best solution in generation 0 is: x = [3, 2, 1, 5, 4] f(x) = 28
# Best solution in generation 1 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 2 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 3 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 4 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 5 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 6 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 7 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 8 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 9 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 10 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 11 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 12 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 13 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 14 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 15 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 16 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 17 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 18 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 19 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 20 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 21 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 22 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 23 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 24 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 25 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 26 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 27 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 28 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 29 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 30 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 31 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 32 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 33 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 34 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 35 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 36 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 37 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 38 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 39 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 40 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 41 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 42 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 43 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 44 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 45 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 46 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 47 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 48 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 49 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 50 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 51 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 52 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 53 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 54 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 55 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 56 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 57 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 58 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 59 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 60 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 61 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 62 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 63 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 64 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 65 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 66 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 67 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 68 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 69 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 70 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 71 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 72 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 73 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 74 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 75 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 76 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 77 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 78 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 79 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 80 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 81 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 82 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 83 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 84 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 85 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 86 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 87 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 88 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 89 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 90 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 91 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 92 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 93 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 94 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 95 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 96 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 97 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 98 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best solution in generation 99 is: x = [2, 1, 3, 5, 4] f(x) = 27
# Best path:  [0, 2, 1, 3, 5, 4]
# With cost: 27
